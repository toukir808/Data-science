# %%
import pandas as pd

# %%
import json
from pandas import json_normalize

# Load JSON
with open(r"C:\Users\niyam\Desktop\excel assighnments\MLR\multiple-linear-regression-dataset-metadata.json") as f:
    data = json.load(f)

# Flatten nested JSON into DataFrame
df = json_normalize(data)
print(df.head())
# Out:
#                                     alternateName  \
# 0  Very Simple Multiple Linear Regression Dataset
#
#                            conformsTo  \
# 0  http://mlcommons.org/croissant/1.0
#
#                                         distribution  \
# 0  [{'contentUrl': 'https://www.kaggle.com/api/v1...
#
#                                            recordSet  version  \
# 0  [{'field': [{'dataType': ['sc:Integer'], 'sour...        1
#
#                                             keywords  isAccessibleForFree  \
# 0  [task > linear regression, data type > tabular...                 True
#
#                                         thumbnailUrl            dateModified  \
# 0  https://storage.googleapis.com/kaggle-datasets...  2022-08-14T08:45:32.11
#
#                  datePublished  ... includedInDataCatalog.name  \
# 0  2022-08-14T15:51:00.5455668  ...                     Kaggle
#
#   includedInDataCatalog.url creator.@type        creator.name  \
# ...

# %%
df
# Out:
#                                     alternateName  \
# 0  Very Simple Multiple Linear Regression Dataset
#
#                            conformsTo  \
# 0  http://mlcommons.org/croissant/1.0
#
#                                         distribution  \
# 0  [{'contentUrl': 'https://www.kaggle.com/api/v1...
#
#                                            recordSet  version  \
# 0  [{'field': [{'dataType': ['sc:Integer'], 'sour...        1
#
#                                             keywords  isAccessibleForFree  \
# 0  [task > linear regression, data type > tabular...                 True
#
#                                         thumbnailUrl            dateModified  \
# 0  https://storage.googleapis.com/kaggle-datasets...  2022-08-14T08:45:32.11
#
#                  datePublished  ... includedInDataCatalog.name  \
# 0  2022-08-14T15:51:00.5455668  ...                     Kaggle
#
#   includedInDataCatalog.url creator.@type        creator.name  \
# ...
